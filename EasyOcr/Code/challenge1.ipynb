# %%
import easyocr
import cv2
import numpy as np
import torch
import os

# %% [markdown]
# ## Module Two.
# ---

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "" 

original_is_available = torch.cuda.is_available
torch.cuda.is_available = lambda: False


image = cv2.imread('../datasets/Page_Level_Test_Set/image.png')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Simple binary thresholding (less memory intensive)
_, thresh = cv2.threshold(gray, 150, 255, cv2.THRESH_BINARY)

cv2.imwrite('preprocessed.jpg', thresh)

print("Initializing EasyOCR with CPU...")
reader = easyocr.Reader(['en'], gpu=False, download_enabled=False)

print("Performing OCR...")
results = reader.readtext('preprocessed.jpg', 
                        paragraph=False,
                        decoder='greedy',  
                        batch_size=1,      
                        text_threshold=0.7,
                        width_ths=0.7,
                        height_ths=0.7)

# Print raw results
print("Raw OCR Results:")
print("-" * 50)
for bbox, text, conf in results:
    print(f"Text: {text} | Confidence: {conf:.2f}")
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# Initializing EasyOCR with CPU...
# Performing OCR...
# Raw OCR Results:
# --------------------------------------------------
# Text: Gone With The Wind | Confidence: 0.97
# Text: Chapter One | Confidence: 1.00
# Text: Scarlett O'Hara was not beautiful; but men seldom realized it when caught | Confidence: 0.61
# Text: by hcr charm as thc Tarlcton twins Wcrc: In hcr facc wcrc too sharply | Confidence: 0.60
# Text: blendledl the clelicale {ealures of Hier molher; a Coasl arislocral o French | Confidence: 0.32
# Text: descent; and the heavy ones of her florid Irish father, But it was an aresting | Confidence: 0.76
# Text: face, pointed of chin; square of jaw. Iler eyes were | Confidence: 0.53
# Text: green without a | Confidence: 0.92
# Text: touch of hazel, starred with bristly black lashes and slightly tilted at the ends. | Confidence: 0.58
# Text: Abovc   thcm, hcr  thick   black   brows   slantcd   upward, cutting a startling | Confidence: 0.34
# Text: oblique line in her  magolia-whiite skin-that  skin $0 prized by Southern | Confidence: 0.16
# Text: women and s0 carefully guarded with bonnets, veils and mittens against hot | Confidence: 0.85
# Text: Georgia suns; | Confidence: 0.62
# Text: Seated with Stuart and Brent Tarleton in the cool shade of the porch of | Confidence: 0.74
# Text: Tara, hcr fathcr's plantation, that bright April aftcrnoon of 1864, shc madc | Confidence: 0.52
# Text: a prelly piclure. Her new green (lowered-muslin dress spread ils twelve | Confidence: 0.29
# Text: yards   of billowing   material | Confidence: 0.88
# Text: over   her  hoops  ad   exactly   matched  the | Confidence: 0.43
# Text: flat-heeled green morocco slippers her father had recently brought her from | Confidence: 0.63
# Text: Atlanta | Confidence: 1.00
# Text: The   dress   set  off to perfection  the   seventeen-inch   waist; the | Confidence: 0.27
# Text: smallest in three counties; and the tightly | Confidence: 0.84
# Text: basque showed breasts well | Confidence: 0.73
# Text: malured [or her sixleen years. Bul or all the modesty o her   spreading | Confidence: 0.23
# Text: skirts, the demureness of hair  netted  smoothly into | Confidence: 0.48
# Text: a chignon ad the | Confidence: 0.81
# Text: quietness of small white hands folded in her | Confidence: 0.96
# Text: her true self was poorly | Confidence: 0.97
# Text: concealed The green eyes in the carefully sweet face were turbulent; willful, | Confidence: 0.63
# Text: lusty with life, distinctly at variance   with  her  decorous  demeanor. Her | Confidence: 0.33
# Text: marmners had been imposed upor her by her mothers gentle admonitions | Confidence: 0.60
# Text: and   the   sterner   discipline | Confidence: 0.60
# Text: of her  mammy;   her   eyes | Confidence: 0.53
# Text: were   her | Confidence: 0.66
# Text: Own. | Confidence: 0.59
# Text: On either side of her; the twins lounged easily in their chairs; squinting | Confidence: 0.64
# Text: at the   sunlight   through   tall  mint-garnished glasses as | Confidence: 0.45
# Text: laughed and | Confidence: 0.89
# Text: talkcd, thcir long lcgs, bootcd to thc kncc and thick with saddlc musclcs, | Confidence: 0.57
# Text: crossed negligently. Nineleen years old, six feet two inches tall, | Confidence: 0.60
# Text: of bone | Confidence: 0.55
# Text: and hard of muscle, with sunburned faces ad deep auburn hair, their eyes | Confidence: 0.64
# Text: merry and  arrogant,  their   bodies   clothed in  identical  blue | Confidence: 0.40
# Text: coats   and | Confidence: 0.71
# Text: mustard-colored breeches, they were as much alike aS two holls of cotton: | Confidence: 0.57
# Text: Outside, the late afternoon sun slanted down in the yard, throwing into | Confidence: 0.55
# Text: pale | Confidence: 1.00
# Text: fitting | Confidence: 1.00
# Text: lap, | Confidence: 0.85
# Text: they | Confidence: 1.00
# Text: long | Confidence: 0.99

# %% [markdown]
# ## POST OCR PROCESSING.
# ---

# %%
import re
from difflib import get_close_matches

# %%
from spellchecker import SpellChecker
spell = SpellChecker()

# %%
def post_process(results):
    processed_results = []
    concatenated_text = ""
    
    for bbox, text, conf in results:
        if isinstance(text, str):
            # Clean and process the text
            cleaned_text = re.sub(r'[^a-zA-Z0-9\s]', '', text).strip()

            if cleaned_text:
                processed_results.append({
                    'bbox': bbox,
                    'text': cleaned_text,
                    'confidence': conf
                })
                concatenated_text += cleaned_text + " "
    
    concatenated_text = concatenated_text.strip()
    
    print("\nPost-processed OCR Results:")
    print("-" * 50)
    for result in processed_results:
        print(f"Text: {result['text']}")
        print(f"Confidence: {result['confidence']:.2f}")
        print("-" * 30)
    
    print("\nConcatenated Text:")
    print("-" * 50)
    print(concatenated_text)
    
    return processed_results, concatenated_text

final_results, concatenated_text = post_process(results)
with open('ocr_output.txt', 'w', encoding='utf-8') as f:
    f.write(concatenated_text)
print(f"\nOutput saved to ocr_output.txt")
# Out:
# Post-processed OCR Results:
# --------------------------------------------------
# Text: Gone With The Wind
# Confidence: 0.97
# ------------------------------
# Text: Chapter One
# Confidence: 1.00
# ------------------------------
# Text: Scarlett OHara was not beautiful but men seldom realized it when caught
# Confidence: 0.61
# ------------------------------
# Text: by hcr charm as thc Tarlcton twins Wcrc In hcr facc wcrc too sharply
# Confidence: 0.60
# ------------------------------
# Text: blendledl the clelicale ealures of Hier molher a Coasl arislocral o French
# Confidence: 0.32
# ------------------------------
# Text: descent and the heavy ones of her florid Irish father But it was an aresting
# Confidence: 0.76
# ------------------------------
# Text: face pointed of chin square of jaw Iler eyes were
# Confidence: 0.53
# ------------------------------
# Text: green without a
# Confidence: 0.92
# ------------------------------
# Text: touch of hazel starred with bristly black lashes and slightly tilted at the ends
# Confidence: 0.58
# ------------------------------
# Text: Abovc   thcm hcr  thick   black   brows   slantcd   upward cutting a startling
# Confidence: 0.34
# ------------------------------
# Text: oblique line in her  magoliawhiite skinthat  skin 0 prized by Southern
# Confidence: 0.16
# ------------------------------
# Text: women and s0 carefully guarded with bonnets veils and mittens against hot
# Confidence: 0.85
# ------------------------------
# Text: Georgia suns
# Confidence: 0.62
# ------------------------------
# Text: Seated with Stuart and Brent Tarleton in the cool shade of the porch of
# Confidence: 0.74
# ------------------------------
# Text: Tara hcr fathcrs plantation that bright April aftcrnoon of 1864 shc madc
# Confidence: 0.52
# ------------------------------
# Text: a prelly piclure Her new green loweredmuslin dress spread ils twelve
# Confidence: 0.29
# ------------------------------
# Text: yards   of billowing   material
# Confidence: 0.88
# ------------------------------
# Text: over   her  hoops  ad   exactly   matched  the
# Confidence: 0.43
# ------------------------------
# Text: flatheeled green morocco slippers her father had recently brought her from
# Confidence: 0.63
# ------------------------------
# Text: Atlanta
# Confidence: 1.00
# ------------------------------
# Text: The   dress   set  off to perfection  the   seventeeninch   waist the
# Confidence: 0.27
# ------------------------------
# Text: smallest in three counties and the tightly
# Confidence: 0.84
# ------------------------------
# Text: basque showed breasts well
# Confidence: 0.73
# ------------------------------
# Text: malured or her sixleen years Bul or all the modesty o her   spreading
# Confidence: 0.23
# ------------------------------
# Text: skirts the demureness of hair  netted  smoothly into
# Confidence: 0.48
# ------------------------------
# Text: a chignon ad the
# Confidence: 0.81
# ------------------------------
# Text: quietness of small white hands folded in her
# Confidence: 0.96
# ------------------------------
# Text: her true self was poorly
# Confidence: 0.97
# ------------------------------
# Text: concealed The green eyes in the carefully sweet face were turbulent willful
# Confidence: 0.63
# ------------------------------
# Text: lusty with life distinctly at variance   with  her  decorous  demeanor Her
# Confidence: 0.33
# ------------------------------
# Text: marmners had been imposed upor her by her mothers gentle admonitions
# Confidence: 0.60
# ------------------------------
# Text: and   the   sterner   discipline
# Confidence: 0.60
# ------------------------------
# Text: of her  mammy   her   eyes
# Confidence: 0.53
# ------------------------------
# Text: were   her
# Confidence: 0.66
# ------------------------------
# Text: Own
# Confidence: 0.59
# ------------------------------
# Text: On either side of her the twins lounged easily in their chairs squinting
# Confidence: 0.64
# ------------------------------
# Text: at the   sunlight   through   tall  mintgarnished glasses as
# Confidence: 0.45
# ------------------------------
# Text: laughed and
# Confidence: 0.89
# ------------------------------
# Text: talkcd thcir long lcgs bootcd to thc kncc and thick with saddlc musclcs
# Confidence: 0.57
# ------------------------------
# Text: crossed negligently Nineleen years old six feet two inches tall
# Confidence: 0.60
# ------------------------------
# Text: of bone
# Confidence: 0.55
# ------------------------------
# Text: and hard of muscle with sunburned faces ad deep auburn hair their eyes
# Confidence: 0.64
# ------------------------------
# Text: merry and  arrogant  their   bodies   clothed in  identical  blue
# Confidence: 0.40
# ------------------------------
# Text: coats   and
# Confidence: 0.71
# ------------------------------
# Text: mustardcolored breeches they were as much alike aS two holls of cotton
# Confidence: 0.57
# ------------------------------
# Text: Outside the late afternoon sun slanted down in the yard throwing into
# Confidence: 0.55
# ------------------------------
# Text: pale
# Confidence: 1.00
# ------------------------------
# Text: fitting
# Confidence: 1.00
# ------------------------------
# Text: lap
# Confidence: 0.85
# ------------------------------
# Text: they
# Confidence: 1.00
# ------------------------------
# Text: long
# Confidence: 0.99
# ------------------------------
#
# Concatenated Text:
# --------------------------------------------------
# Gone With The Wind Chapter One Scarlett OHara was not beautiful but men seldom realized it when caught by hcr charm as thc Tarlcton twins Wcrc In hcr facc wcrc too sharply blendledl the clelicale ealures of Hier molher a Coasl arislocral o French descent and the heavy ones of her florid Irish father But it was an aresting face pointed of chin square of jaw Iler eyes were green without a touch of hazel starred with bristly black lashes and slightly tilted at the ends Abovc   thcm hcr  thick   black   brows   slantcd   upward cutting a startling oblique line in her  magoliawhiite skinthat  skin 0 prized by Southern women and s0 carefully guarded with bonnets veils and mittens against hot Georgia suns Seated with Stuart and Brent Tarleton in the cool shade of the porch of Tara hcr fathcrs plantation that bright April aftcrnoon of 1864 shc madc a prelly piclure Her new green loweredmuslin dress spread ils twelve yards   of billowing   material over   her  hoops  ad   exactly   matched  the flatheeled green morocco slippers her father had recently brought her from Atlanta The   dress   set  off to perfection  the   seventeeninch   waist the smallest in three counties and the tightly basque showed breasts well malured or her sixleen years Bul or all the modesty o her   spreading skirts the demureness of hair  netted  smoothly into a chignon ad the quietness of small white hands folded in her her true self was poorly concealed The green eyes in the carefully sweet face were turbulent willful lusty with life distinctly at variance   with  her  decorous  demeanor Her marmners had been imposed upor her by her mothers gentle admonitions and   the   sterner   discipline of her  mammy   her   eyes were   her Own On either side of her the twins lounged easily in their chairs squinting at the   sunlight   through   tall  mintgarnished glasses as laughed and talkcd thcir long lcgs bootcd to thc kncc and thick with saddlc musclcs crossed negligently Nineleen years old six feet two inches tall of bone and hard of muscle with sunburned faces ad deep auburn hair their eyes merry and  arrogant  their   bodies   clothed in  identical  blue coats   and mustardcolored breeches they were as much alike aS two holls of cotton Outside the late afternoon sun slanted down in the yard throwing into pale fitting lap they long
#
# Output saved to ocr_output.txt
